# %% [markdown]
# <a href="https://colab.research.google.com/github/mzagoska/II/blob/main/Course_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Курсовая работа на тему "Дата-сеты"
# Загоска Максим, группа М80-107-22

# %% [markdown]
# # Задание:
# 1. Выбор своего датасета (условие — выполнено в виде интерактивной презентации
# в юпитере)
# Нужно попытаться визуализировать экземпляр данных
# 2. найти публикацию\статью про датасет, внедрить ссылку и кратко описать в
# презентации (+ какие популярные модели используются)
# 3. Пример данных с разметкой + пример кода для загрузки тестового набора
# 4. Пример применения готовой модели на этих данных

# %% [markdown]
# # Описание дата-сета
# Дата-сет - Heart Attack Analysis & Prediction Dataset (ссылка: https://www.kaggle.com/datasets/rashikrahmanpritom/heart-attack-analysis-prediction-dataset)
#
# **Об этом дата-сете:**
#
# - Age :  Возраст пациента
#
# - Sex : Пол пациента
#
# - exang: стенокардия, вызванная физической нагрузкой (1 = да; 0 = нет)
#
# - ca: количество крупных сосудов (0-3)
#
# - cp : Тип боли в груди Тип боли в груди
#
#       Value 1: типичная стенокардия
#
#       Value 2: атипичная стенокардия
#
#       Value 3: неангинозная боль
#
#       Value 4: бессимптомный
#
# - trtbps : артериальное давление в покое (в мм рт. ст.)
#
# - chol : холестораль в мг/дл, полученный с помощью датчика ИМТ
#
# - fbs : (уровень сахара в крови натощак > 120 мг/дл) (1 = верно; 0 = неверно)
#
# - rest_ecg : результаты электрокардиографии в покое
#
#       Value 0: нормальный
#
#       Value 1: наличие аномалии ST-T (инверсия зубца T и/или элевация или депрессия ST > 0,05 мВ)
#
#       Value 2: указание на возможную или определенную гипертрофию левого желудочка по критериям Эстеса.
#
# - thalach : максимальная частота сердечных сокращений
#
# - target : 0 = меньше вероятность сердечного приступа 1 = больше вероятность сердечного приступа

# %% [markdown]
# # Загрузка дата-сета

# %% [markdown]
# Импорт необходимых библиотек

# %%
import seaborn as sns
import plotly.express as px
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler 
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier  
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# %%
heart_df=pd.read_csv('/heart.csv')
heart_df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# # Предварительная обработка
#
# Информация о дата-сете: типы данных атрибутов, форма, количество нулей в строке относительно столбца.

# %%
heart_df.info()
print('Number of rows are',heart_df.shape[0], 'and number of columns are ',heart_df.shape[1])
# Проверка нулевых значений
heart_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# Number of rows are 303 and number of columns are  14
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
# Проверка дубликатов
heart_df[heart_df.duplicated()]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 164   38    1   2     138   175    0        1       173     0      0.0    2
#
#      caa  thall  output
# 164    4      2       1

# %%
# Удаление дубликатов
heart_df.drop_duplicates(keep='first',inplace=True)
heart_df[heart_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trtbps, chol, fbs, restecg, thalachh, exng, oldpeak, slp, caa, thall, output]
# Index: []

# %% [markdown]
# # Сбор статистической информации

# %%
heart_df.describe()
# Out:
#              age         sex          cp      trtbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# std      0.526027   22.903527    0.470196    1.161452    0.616274    1.006748
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.250000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall      output
# count  302.000000  302.000000
# mean     2.314570    0.543046
# std      0.613026    0.498970
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
# матрица корреляции
cor_mat = heart_df.corr()
cor_mat
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trtbps    0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalachh -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exng      0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slp      -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# caa       0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thall     0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# output   -0.221476 -0.283609  0.432080 -0.146269 -0.081437 -0.026826
#
#            restecg  thalachh      exng   oldpeak       slp       caa  \
# age      -0.111590 -0.395235  0.093216  0.206040 -0.164124  0.302261
# sex      -0.060351 -0.046439  0.143460  0.098322 -0.032990  0.113060
# cp        0.041561  0.293367 -0.392937 -0.146692  0.116854 -0.195356
# trtbps   -0.115367 -0.048023  0.068526  0.194600 -0.122873  0.099248
# chol     -0.147602 -0.005308  0.064099  0.050086  0.000417  0.086878
# fbs      -0.083081 -0.007169  0.024729  0.004514 -0.058654  0.144935
# restecg   1.000000  0.041210 -0.068807 -0.056251  0.090402 -0.083112
# thalachh  0.041210  1.000000 -0.377411 -0.342201  0.384754 -0.228311
# exng     -0.068807 -0.377411  1.000000  0.286766 -0.256106  0.125377
# oldpeak  -0.056251 -0.342201  0.286766  1.000000 -0.576314  0.236560
# slp       0.090402  0.384754 -0.256106 -0.576314  1.000000 -0.092236
# caa      -0.083112 -0.228311  0.125377  0.236560 -0.092236  1.000000
# thall    -0.010473 -0.094910  0.205826  0.209090 -0.103314  0.160085
# output    0.134874  0.419955 -0.435601 -0.429146  0.343940 -0.408992
#
#              thall    output
# age       0.065317 -0.221476
# sex       0.211452 -0.283609
# cp       -0.160370  0.432080
# trtbps    0.062870 -0.146269
# chol      0.096810 -0.081437
# fbs      -0.032752 -0.026826
# restecg  -0.010473  0.134874
# thalachh -0.094910  0.419955
# exng      0.205826 -0.435601
# oldpeak   0.209090 -0.429146
#
.09832173325423298,-0.14669224707212516,0.1945999503128808,0.050086024023738865,0.004514274973532866,-0.056250713595255936,-0.3422007459247005,0.2867663364924335,1.0,-0.5763143815309939,0.23656044177478658,0.2090904909004058,-0.42914583288673813],[-0.16412423366806822,-0.03298963307429071,0.11685419420886575,-0.12287292844741415,0.000416658293245955,-0.058653541394914625,0.09040215246954555,0.38475438059767736,-0.2561062438300406,-0.5763143815309939,1.0,-0.09223636675937119,-0.10331366531177844,0.34393953248938713],[0.30226120969724174,0.11306039137632619,-0.19535634467105176,0.09924834090336425,0.08687793662520914,0.14493474913217871,-0.08311244328643051,-0.2283110828854547,0.1253771017635063,0.23656044177 ...

# %% [markdown]
# # Визуализация дата-сета

# %% [markdown]
# **Возраст**

# %%
heart_df['age'].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77])

# %%
heart_df['age'].nunique()
# Out:
# 41

# %%
age_lst = heart_df['age'].value_counts().index
nop_age = heart_df['age'].value_counts().values
print("Уникальный возраст:  ")
print(age_lst)
print("Кол-во уникальных возрастов:  ")
print(nop_age)
# Out:
# Уникальный возраст:
# Int64Index([58, 57, 54, 59, 52, 51, 62, 56, 44, 60, 41, 64, 67, 63, 43, 55, 42,
#             61, 65, 53, 45, 50, 48, 46, 66, 47, 49, 70, 39, 68, 35, 71, 40, 69,
#             34, 37, 38, 29, 74, 76, 77],
#            dtype='int64')
# Кол-во уникальных возрастов:
# [19 17 16 14 13 12 11 11 11 11 10 10  9  9  8  8  8  8  8  8  8  7  7  7
#   7  5  5  4  4  4  4  3  3  3  2  2  2  1  1  1  1]

# %%
fig = px.histogram(heart_df, 
             x='age',
             nbins=10,
             title='Сопоставление возраст и количества каждого из возрастов'
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7bf49f56-7627-47d7-9b3e-3190584dd76a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bf49f56-7627-47d7-9b3e-3190584dd76a")) {                    Plotly.newPlot(                        "7bf49f56-7627-47d7-9b3e-3190584dd76a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":10,"offsetgroup":"","orientation":"v","showlegend":false,"x":[63,37,41,56,57,57,56,44,52,57,54,48,49,64,58,50,58,66,43,69,59,44,42,61,40,71,59,51,65,53,41,65,44,54,51,46,54,54,65,65,51,48,45,53,39,52,44,47,53,53,51,66,62,44,63,52,48,45,34,57,71,54,52,41,58,35,51,45,44,62,54,51,29,51,43,55,51,59,52,58,41,45,60,52,42,67,68,46,54,58,48,57,52,54,45,53,62,52,43,53,42,59,63,42,50,68,69,45,50,50,64,57,64,43,55,37,41,56,46,46,64,59,41,54,39,34,47,67,52,74,54,49,42,41,41,49,60,62,57,64,51,43,42,67,76,70,44,60,44,42,66,71,64,66,39,58,47,35,58,56,56,55,41,38,67,67,62,63,53,56,48,58,58,60,40,60,64,43,57,55,65,61,58,50,44,60,54,50,41,51,58,54,60,60,59,46,67,62,65,44,60,58,68,62,52,59,60,49,59,57,61,39,61,56,43,62,63,65,48,63,55,65,56,54,70,62,35,59,64,47,57,55,64,70,51,58,60,77,35,70,59,64,57,56,48,56,66,54,69,51,43,62,67,59,45,58,50,62,38,66,52,53,63,54,66,55,49,54,56,46,61,67,58,47,52,58,57,58,61,42,52,59,40,61,46,59,57,57,55,61,58,58,67,44,63,63,59,57,45,68,57,57],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555 ...

# %%
fig = px.histogram(heart_df[heart_df['output'] == 1], 
             x='age',
             nbins=10,
             title='Сопоставление возраста и числа сердечных приступов'
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9a0d27ad-af02-4165-a3c4-b2f02f1187ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a0d27ad-af02-4165-a3c4-b2f02f1187ff")) {                    Plotly.newPlot(                        "9a0d27ad-af02-4165-a3c4-b2f02f1187ff",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":10,"offsetgroup":"","orientation":"v","showlegend":false,"x":[63,37,41,56,57,57,56,44,52,57,54,48,49,64,58,50,58,66,43,69,59,44,42,61,40,71,59,51,65,53,41,65,44,54,51,46,54,54,65,65,51,48,45,53,39,52,44,47,53,53,51,66,62,44,63,52,48,45,34,57,71,54,52,41,58,35,51,45,44,62,54,51,29,51,43,55,51,59,52,58,41,45,60,52,42,67,68,46,54,58,48,57,52,54,45,53,62,52,43,53,42,59,63,42,50,68,69,45,50,50,64,57,64,43,55,37,41,56,46,46,64,59,41,54,39,34,47,67,52,74,54,49,42,41,41,49,60,62,57,64,51,43,42,67,76,70,44,60,44,42,66,71,64,66,39,58,47,35,58,56,56,55,41,38],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.66666666666 ...

# %% [markdown]
# **Вывод:** Наибольшее количество сердечных приступов наблюдается в возрастной группе 50-54 года.

# %% [markdown]
# **Пол**

# %%
sex_name = ['Мужчины', 'Женщины']
sex_count = heart_df['sex'].value_counts().values

fig = px.histogram(x=sex_name, 
             y=sex_count,
             color = sex_name,
             title='Сопоставление пола и числа сердечных приступов'
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="20cde384-5bc7-4969-8443-df0224673219" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20cde384-5bc7-4969-8443-df0224673219")) {                    Plotly.newPlot(                        "20cde384-5bc7-4969-8443-df0224673219",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=\u041c\u0443\u0436\u0447\u0438\u043d\u044b<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"\u041c\u0443\u0436\u0447\u0438\u043d\u044b","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u041c\u0443\u0436\u0447\u0438\u043d\u044b","offsetgroup":"\u041c\u0443\u0436\u0447\u0438\u043d\u044b","orientation":"v","showlegend":true,"x":["\u041c\u0443\u0436\u0447\u0438\u043d\u044b"],"xaxis":"x","y":[206],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=\u0416\u0435\u043d\u0449\u0438\u043d\u044b<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"\u0416\u0435\u043d\u0449\u0438\u043d\u044b","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u0416\u0435\u043d\u0449\u0438\u043d\u044b","offsetgroup":"\u0416\u0435\u043d\u0449\u0438\u043d\u044b","orientation":"v","showlegend":true,"x":["\u0416\u0435\u043d\u0449\u0438\u043d\u044b"],"xaxis":"x","y":[96],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"hist ...

# %% [markdown]
# **Вывод:** явной связи с полом не наблюдается

# %% [markdown]
# **Боль в груди**

# %%
cp_type = ['Typical Angina(0)', 'Atypical Angina-1', 'Non-anginal Pain-2', 'Asymptomatic-3']
cp_type_count = heart_df['cp'].value_counts().values

# %%
fig = px.histogram(x=cp_type,
             y=cp_type_count, 
            color=cp_type,
             title='Сопоставление боли в груди с типами боли'
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3749b07d-8114-40ad-b9af-f5b1985dcf0f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3749b07d-8114-40ad-b9af-f5b1985dcf0f")) {                    Plotly.newPlot(                        "3749b07d-8114-40ad-b9af-f5b1985dcf0f",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Typical Angina(0)<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Typical Angina(0)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Typical Angina(0)","offsetgroup":"Typical Angina(0)","orientation":"v","showlegend":true,"x":["Typical Angina(0)"],"xaxis":"x","y":[143],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Atypical Angina-1<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Atypical Angina-1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Atypical Angina-1","offsetgroup":"Atypical Angina-1","orientation":"v","showlegend":true,"x":["Atypical Angina-1"],"xaxis":"x","y":[86],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Non-anginal Pain-2<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Non-anginal Pain-2","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Non-anginal Pain-2","offsetgroup":"Non-anginal Pain-2","orientation":"v","showlegend":true,"x":["Non-anginal Pain-2"],"xaxis":"x","y":[50],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Asymptomatic-3<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Asymptomatic-3","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Asymptomatic-3","offsetgroup":"Asymptomatic-3","orientation":"v","showlegend":true,"x":["Asymptomatic-3"],"xaxis":"x","y":[23],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"# ...

# %%
cp_type = ['Typical Angina(0)', 'Atypical Angina-1', 'Non-anginal Pain-2', 'Asymptomatic-3']
cp_type_count = heart_df[heart_df['output'] == 1]['cp'].value_counts().values

fig = px.histogram(x=cp_type,
             y=cp_type_count, 
            color=cp_type,
             title='Сопоставление типов боли с кол-вом средечных приступов'
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6b30c8a5-28d7-47cd-bb9e-9833ff26c148" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b30c8a5-28d7-47cd-bb9e-9833ff26c148")) {                    Plotly.newPlot(                        "6b30c8a5-28d7-47cd-bb9e-9833ff26c148",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Typical Angina(0)<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Typical Angina(0)","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Typical Angina(0)","offsetgroup":"Typical Angina(0)","orientation":"v","showlegend":true,"x":["Typical Angina(0)"],"xaxis":"x","y":[68],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Atypical Angina-1<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Atypical Angina-1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Atypical Angina-1","offsetgroup":"Atypical Angina-1","orientation":"v","showlegend":true,"x":["Atypical Angina-1"],"xaxis":"x","y":[41],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Non-anginal Pain-2<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Non-anginal Pain-2","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Non-anginal Pain-2","offsetgroup":"Non-anginal Pain-2","orientation":"v","showlegend":true,"x":["Non-anginal Pain-2"],"xaxis":"x","y":[39],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"color=Asymptomatic-3<br>x=%{x}<br>sum of y=%{y}<extra></extra>","legendgroup":"Asymptomatic-3","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Asymptomatic-3","offsetgroup":"Asymptomatic-3","orientation":"v","showlegend":true,"x":["Asymptomatic-3"],"xaxis":"x","y":[16],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#f ...

# %% [markdown]
# **Вывод:** Типичная ангина имеет наибольшее количество сердечных приступов, т.е. 68.

# %% [markdown]
# # Обучение модели
#
# Обученную модель можно использовать для предсказания вероятности сердечного признака обследуемого на данных, полученных в результате врачебного обследования.

# %% [markdown]
# **Разделение на тестовую и обучающую выборки**
# Дата-сет был разделен на обучающую и тестовую выборки. Размер обучающей выборки - 80%, тестовой - 20%.

# %%
X = heart_df.iloc[:, :-1].values
y = heart_df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state= 0)
print('Shape for training data', X_train.shape, y_train.shape)
print('Shape for testing data', X_test.shape, y_test.shape)
# Out:
# Shape for training data (241, 13) (241,)
# Shape for testing data (61, 13) (61,)

# %% [markdown]
# **Масштабирование**

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Обучение модели
# Путем подбора наилучшего алгоритма обучения для получения максимальной точности, лучшую точность показал алгоритм - **Support vector machine** (список используемых алгоритмов: Logistic Regression, Gaussian Naive Bayes, Bernoulli Naive Bayes, Support Vector Machine, K Nearest Neighbours, X Gradient Boosting).

# %%
svm_model = SVC()
svm_model.fit(X_train, y_train)
  
predicted = svm_model.predict(X_test)
print("The accuracy of SVM is : ", accuracy_score(y_test, predicted)*100, "%")
# Out:
# The accuracy of SVM is :  93.44262295081968 %
